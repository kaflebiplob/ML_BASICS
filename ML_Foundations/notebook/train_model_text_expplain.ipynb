# %%
# SUPERVISED LEARNING

# %%
# Training = studying the textbook
# Validation = practicing with questions you haven't seen before
# Testing = taking the actual exam

# %%
#  100% Data
#    │
#    ├── 80% Training
#    │
#    └── 20% Test

# %%
# We need to check each and everytest so that we will know which of them are linked with eachother

# %%
# IMPORTANT ->   ML Project
    #                  │
    #       ┌──────────┴──────────┐
    #       ↓                     ↓
    #   Data quality          Model quality
    #       │                     │
    #  Missing values        Overfitting?
    #  Duplicates            Underfitting?
    #  Outliers              Generalization?
    #       │                     │
    #       └──────────┬──────────┘
    #                  ↓
    #           Final evaluation
    #                  ↓
    #           Deploy the model
