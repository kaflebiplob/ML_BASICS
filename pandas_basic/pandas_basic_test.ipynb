# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
# create Dataframe

df = pd.DataFrame([11,12,13],columns=['name'])
print(df)
# Out:
#    name
# 0    11
# 1    12
# 2    13

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'name':['biplob','ram','hari','krishna'],
    'age':[23,80,40,10],
    'salary':[34000,70000,50000,100000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age  salary
# 0   biplob   23   34000
# 1      ram   80   70000
# 2     hari   40   50000
# 3  krishna   10  100000

# %%
# Basic DataFrame understanding

df.head()
# Out:
#       name  age  salary
# 0   biplob   23   34000
# 1      ram   80   70000
# 2     hari   40   50000
# 3  krishna   10  100000

# %%
df.tail(2)
# Out:
#       name  age  salary
# 2     hari   40   50000
# 3  krishna   10  100000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary'], dtype='str')

# %%
changed_df=df.rename(columns={"name":"Name","age":"Age","salary":"Montlhy_Salary"},inplace=True)

# %%
df
# Out:
#       Name  Age  Montlhy_Salary
# 0   biplob   23           34000
# 1      ram   80           70000
# 2     hari   40           50000
# 3  krishna   10          100000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Montlhy_Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#              Age  Montlhy_Salary
# count   4.000000        4.000000
# mean   38.250000    63500.000000
# std    30.423401    28442.925307
# min    10.000000    34000.000000
# 25%    19.750000    46000.000000
# 50%    31.500000    60000.000000
# 75%    50.000000    77500.000000
# max    80.000000   100000.000000

# %%
# Save and Load data from csv
df.to_csv('test_value.csv',index=False)

# %%
load_df = pd.read_csv('test_value.csv')
load_df
# Out:
#       Name  Age  Montlhy_Salary
# 0   biplob   23           34000
# 1      ram   80           70000
# 2     hari   40           50000
# 3  krishna   10          100000

# %%
# select column

df[['Name']]
# Out:
#       Name
# 0   biplob
# 1      ram
# 2     hari
# 3  krishna

# %%
df[['Name','Age']]
# Out:
#       Name  Age
# 0   biplob   23
# 1      ram   80
# 2     hari   40
# 3  krishna   10

# %%
# select rows
# loc = indexx name baased
df.loc[df.Name=='biplob']
df.loc[(df.Name=='biplob') & (df.Montlhy_Salary >=40000)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Montlhy_Salary]
# Index: []

# %%
# iloc -- index value based
df.iloc[0:2]
# Out:
#      Name  Age  Montlhy_Salary
# 0  biplob   23           34000
# 1     ram   80           70000

# %%
# filter df
df
# Out:
#       Name  Age  Montlhy_Salary
# 0   biplob   23           34000
# 1      ram   80           70000
# 2     hari   40           50000
# 3  krishna   10          100000

# %%
df[(df['Age']>24) & (df['Montlhy_Salary']>=55000)]
# Out:
#   Name  Age  Montlhy_Salary
# 1  ram   80           70000

# %%
df.where(df['Age']>=25,other='Not Eligible')
# Out:
#            Name           Age Montlhy_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1           ram            80          70000
# 2          hari            40          50000
# 3  Not Eligible  Not Eligible   Not Eligible

# %%
df
# Out:
#       Name  Age  Montlhy_Salary
# 0   biplob   23           34000
# 1      ram   80           70000
# 2     hari   40           50000
# 3  krishna   10          100000

# %%
# add new column

df['Team']=['DA','HR','CTO','CEO']

# %%
df
# Out:
#       Name  Age  Montlhy_Salary Team
# 0   biplob   23           34000   DA
# 1      ram   80           70000   HR
# 2     hari   40           50000  CTO
# 3  krishna   10          100000  CEO

# %%
df['Bonus']= df['Montlhy_Salary']*0.2
df
# Out:
#       Name  Age  Montlhy_Salary Team    Bonus
# 0   biplob   23           34000   DA   6800.0
# 1      ram   80           70000   HR  14000.0
# 2     hari   40           50000  CTO  10000.0
# 3  krishna   10          100000  CEO  20000.0

# %%
# add new rows
df.loc[len(df)] =['Shiva','81','115000','chairman','25000']

# %%
df
# Out:
#       Name Age Montlhy_Salary      Team    Bonus
# 0   biplob  23          34000        DA   6800.0
# 1      ram  80          70000        HR  14000.0
# 2     hari  40          50000       CTO  10000.0
# 3  krishna  10         100000       CEO  20000.0
# 4    Shiva  81         115000  chairman    25000

# %%
len(df)
# Out:
# 5

# %%
# update value
df.loc[3, 'Age'] = 50
df
# Out:
#       Name Age Montlhy_Salary      Team    Bonus
# 0   biplob  23          34000        DA   6800.0
# 1      ram  80          70000        HR  14000.0
# 2     hari  40          50000       CTO  10000.0
# 3  krishna  50         100000       CEO  20000.0
# 4    Shiva  81         115000  chairman    25000

# %%
# update value using column name

df.loc[df.Name =='ram','Age']=60

# %%
df
# Out:
#       Name Age Montlhy_Salary      Team    Bonus
# 0   biplob  23          34000        DA   6800.0
# 1      ram  60          70000        HR  14000.0
# 2     hari  40          50000       CTO  10000.0
# 3  krishna  50         100000       CEO  20000.0
# 4    Shiva  81         115000  chairman    25000

# %%
# delete value row and column values

df.drop(df[df.Name== 'biplob'].index,inplace=True) #drop row axis = 0

# %%
df.drop('Bonus',axis=1,inplace=True)

# %%
df
# Out:
#       Name Age Montlhy_Salary      Team
# 1      ram  60          70000        HR
# 2     hari  40          50000       CTO
# 3  krishna  50         100000       CEO
# 4    Shiva  81         115000  chairman

# %%
print(type(df['Age']))
# Out:
# <class 'pandas.Series'>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 1 to 4
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      object
#  2   Montlhy_Salary  4 non-null      object
#  3   Team            4 non-null      str
# dtypes: object(2), str(2)
# memory usage: 260.0+ bytes

# %%
# Sorting value
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

df = df.sort_values('Age', ascending=False)

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team
# 4    Shiva   81         115000  chairman
# 1      ram   60          70000        HR
# 3  krishna   50         100000       CEO
# 2     hari   40          50000       CTO

# %%
# Working with datetime values
df['DOJ']=['2023-01-01','2024-01-10','2024-02-12','2024-10-12']
df
# Out:
#       Name  Age Montlhy_Salary      Team         DOJ
# 4    Shiva   81         115000  chairman  2023-01-01
# 1      ram   60          70000        HR  2024-01-10
# 3  krishna   50         100000       CEO  2024-02-12
# 2     hari   40          50000       CTO  2024-10-12

# %%
df['DOJ'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df.dtypes
# Out:
# Name                         str
# Age                        int64
# Montlhy_Salary            object
# Team                         str
# DOJ               datetime64[us]
# dtype: object

# %%
df1=df['DOJ2']=['01-01-2023','12-01-2024','02-12-2024','18-02-2024']

# %%
df1=df

# %%
df1
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ        DOJ2
# 4    Shiva   81         115000  chairman 2023-01-01  01-01-2023
# 1      ram   60          70000        HR 2024-01-10  12-01-2024
# 3  krishna   50         100000       CEO 2024-02-12  02-12-2024
# 2     hari   40          50000       CTO 2024-10-12  18-02-2024

# %%
df1['DOJ2'].dtypes
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df1['DOJ2']=pd.to_datetime(df['DOJ2'],format='%d-%m-%Y')

# %%
df1['DOJ2'].dtypes
# Out:
# dtype('<M8[us]')

# %%
df1
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ       DOJ2
# 4    Shiva   81         115000  chairman 2023-01-01 2023-01-01
# 1      ram   60          70000        HR 2024-01-10 2024-01-12
# 3  krishna   50         100000       CEO 2024-02-12 2024-12-02
# 2     hari   40          50000       CTO 2024-10-12 2024-02-18

# %%
df.drop('DOJ2',inplace=True,axis=1)
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
df['DOJ'].dt.year
# Out:
# 4    2023
# 1    2024
# 3    2024
# 2    2024
# Name: DOJ, dtype: int32

# %%
print('month:',df['DOJ'].dt.month)
print('day:',df['DOJ'].dt.day)
# Out:
# month: 4     1
# 1     1
# 3     2
# 2    10
# Name: DOJ, dtype: int32
# day: 4     1
# 1    10
# 3    12
# 2    12
# Name: DOJ, dtype: int32

# %%
import numpy as np

# %%
df.loc[df.Name =='hari','Montlhy_Salary']=np.nan

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40            NaN       CTO 2024-10-12

# %%
df.isnull()
# Out:
#     Name    Age  Montlhy_Salary   Team    DOJ
# 4  False  False           False  False  False
# 1  False  False           False  False  False
# 3  False  False           False  False  False
# 2  False  False            True  False  False

# %%
df.isnull().sum()
# Out:
# Name              0
# Age               0
# Montlhy_Salary    1
# Team              0
# DOJ               0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40              0       CTO 2024-10-12

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40            NaN       CTO 2024-10-12

# %%
df.loc[df['Name']=='hari','Montlhy_Salary']=50000

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
df.rename(columns={'Montlhy_Salary':'Monthly_Salary'})
# Out:
#       Name  Age Monthly_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
df.loc[df['Name'] == 'Shiva', 'Monthly_Salary'] = 115000
df.loc[df['Name'] == 'ram', 'Monthly_Salary'] = 80000
df.loc[df['Name'] == 'krishna', 'Monthly_Salary'] = 60000

# %%
df
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ  Monthly_Salary
# 4    Shiva   81         115000  chairman 2023-01-01        115000.0
# 1      ram   60          70000        HR 2024-01-10         80000.0
# 3  krishna   50         100000       CEO 2024-02-12         60000.0
# 2     hari   40          50000       CTO 2024-10-12             NaN

# %%
df.drop('Monthly_Salary',axis=1)
# Out:
#       Name  Age Montlhy_Salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
df.rename(columns={'Montlhy_Salary':'Monthly_salary'},inplace=True)
df
# Out:
#       Name  Age Monthly_salary      Team        DOJ  Monthly_Salary
# 4    Shiva   81         115000  chairman 2023-01-01        115000.0
# 1      ram   60          70000        HR 2024-01-10         80000.0
# 3  krishna   50         100000       CEO 2024-02-12         60000.0
# 2     hari   40          50000       CTO 2024-10-12             NaN

# %%
df.drop('Monthly_Salary',axis=1,inplace=True)

# %%
df
# Out:
#       Name  Age Monthly_salary      Team        DOJ
# 4    Shiva   81         115000  chairman 2023-01-01
# 1      ram   60          70000        HR 2024-01-10
# 3  krishna   50         100000       CEO 2024-02-12
# 2     hari   40          50000       CTO 2024-10-12

# %%
# Aggregation and groupby
df['Team'].value_counts()
# Out:
# Team
# chairman    1
# HR          1
# CEO         1
# CTO         1
# Name: count, dtype: int64

# %%
df[df['Team']=='CEO'].value_counts()
# Out:
# Name     Age  Monthly_salary  Team  DOJ
# krishna  50   100000          CEO   2024-02-12    1
# Name: count, dtype: int64

# %%
df.groupby('Team')['Monthly_salary'].sum() #Aggregation based on groupby
# Out:
# Team
# CEO         100000
# CTO          50000
# HR           70000
# chairman    115000
# Name: Monthly_salary, dtype: object

# %%
df.groupby('Team').agg({'Monthly_salary':'size','Name':'count'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1744, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1743 try:
# -> 1744     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1745 except Exception as err:
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:988, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     976 """
#     977 Parameters
#     978 ----------
#    (...)    986 np.ndarray or ExtensionArray
#     987 """
# --> 988 result = self._aggregate_series_pure_python(obj, func)
#     989 return obj.array._cast_pointwise_result(result)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:1001, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#    1000 for i, group in enumerate(splitter):
# -> 1001     res = func(group)
#    1002     res = extract_result(res)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2287, in GroupBy.mean.<locals>.<lambda>(x)
#    2284 else:
#    2285     result = self._cython_agg_general(
#    2286         "mean",
# -> 2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8071 """
#    8072 Return the mean of the values over the requested axis.
#    8073
#    (...)   8111 2.0
#    8112 """
# -> 8113 return NDFrame.mean(
#    8114     self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8115 )
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/generic.py:11819, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11817         **kwargs,
#   11818     ) -> Series | float:
# > 11819         return self._stat_function(
#   11820             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/generic.py:11773, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11771         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11772
# > 11773         return self._reduce(
#   11774             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/series.py:7494, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7490         raise TypeError(
#    7491             f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    7492             "with non-numeric dtypes."
#    7493         )
# -> 7494     result = op(delegate, skipna=skipna, **kwds)
#    7496 result = maybe_unbox_numpy_scalar(result)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/nanops.py:149, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     148 else:
# --> 149     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     151 return result
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/nanops.py:408, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     406     mask = isna(values)
# --> 408 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     410 if datetimelike:
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/nanops.py:714, in nanmean(values, axis, skipna, mask)
#     713 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 714 the_sum = _ensure_numeric(the_sum)
#     716 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/nanops.py:1742, in _ensure_numeric(x)
#    1740 if isinstance(x, str):
#    1741     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1742     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1743 try:
#
# TypeError: Could not convert string '115000' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.groupby('Team').agg({'Monthly_salary':'mean','Name':'count'})
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# --> 294     return self.agg_dict_like()
#     295 elif is_list_like(func):
#     296     # we require a list, but not a 'str'
#     297     return self.agg_list_like()
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/apply.py:511, in Apply.agg_dict_like(self)
#     503 def agg_dict_like(self) -> DataFrame | Series:
#     504     """
#     505     Compute aggregation in the case of a dict-like argument.
#     506
#    (...)    509     Result of aggregation.
#     510     """
# --> 511     return self.agg_or_apply_dict_like(op_name="agg")
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/apply.py:1677, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1672     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1674 with com.temp_setattr(
#    1675     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1676 ):
# -> 1677     result_index, result_data = self.compute_dict_like(
#    1678         op_name, selected_obj, selection, kwargs
#    1679     )
#    1680 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1681 return result
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/apply.py:592, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     590 if cols.ndim == 1:
#     591     series = obj._gotitem(key, ndim=1, subset=cols)
# --> 592     results.append(getattr(series, op_name)(how, **kwargs))
#     593     keys.append(key)
#     594 else:
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/generic.py:456, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     454     if engine_kwargs is not None:
#     455         kwargs["engine_kwargs"] = engine_kwargs
# --> 456     return getattr(self, func)(*args, **kwargs)
#     458 elif isinstance(func, abc.Iterable):
#     459     # Catch instances of lists / tuples
#     460     # but not the class list / tuple itself.
#     461     func = maybe_mangle_lambdas(func)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:2295, in SingleBlockManager.grouped_reduce(self, func)
#    2293 def grouped_reduce(self, func):
#    2294     arr = self.array
# -> 2295     res = func(arr)
#    2296     index = default_index(len(res))
#    2298     mgr = type(self).from_array(res, index)
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1805, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1802     return result
#    1804 assert alt is not None
# -> 1805 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806 return result
#
# File /run/media/biplob/e1a9a613-7e49-4b9e-81ed-a1c7ad2b4cae/biplob/MachineLearning/venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1748, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1746     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1747     # preserve the kind of exception that raised
# -> 1748     raise type(err)(msg) from err
#    1750 dtype = ser.dtype
#    1751 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]
