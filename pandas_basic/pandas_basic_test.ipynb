# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
# create Dataframe

df = pd.DataFrame([11,12,13],columns=['name'])
print(df)
# Out:
#    name
# 0    11
# 1    12
# 2    13

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'name':['biplob','ram','hari','krishna'],
    'age':[23,100000,1000000,10000],
    'salary':[34000,10000000,10000000,1000000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       name      age    salary
# 0   biplob       23     34000
# 1      ram   100000  10000000
# 2     hari  1000000  10000000
# 3  krishna    10000   1000000
